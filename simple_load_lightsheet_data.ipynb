# %%
from fish.image.zds import ZDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
base_dir = 'F:/davis/20180314/5dpf_gfap_h2b_gcamp_x_huc_rgeco_x_ec43_opto_2_20180314_161038/'
dset = ZDS(base_dir, parallelism=-1)

# %%
plt.imshow(dset[-1].max(0))

# %%
tmp = dset[:, 10, 1500:1700,600:1200]

# %%
from skimage.io import imsave

# %%
imsave(r'C:\Users\AhrensLab\Desktop\test.tif', tmp)
# Out:
# C:\Anaconda3\lib\site-packages\skimage\io\_io.py:132: UserWarning: C:\Users\AhrensLab\Desktop\test.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
